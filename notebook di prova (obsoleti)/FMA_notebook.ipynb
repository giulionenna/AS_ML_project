# %%
import pandas as pd
import IPython.display as ipd
from sklearn.preprocessing import StandardScaler
from sklearn.svm import SVC
from sklearn.decomposition import PCA
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt
import numpy as np

# %%
tracks = pd.read_csv('Data/fma_metadata/fma_metadata/tracks.csv', header=[0,1], index_col=0) #import using multilabel columns

# %%
ipd.display(tracks['track'].head())
ipd.display(tracks['album'].head())
ipd.display(tracks['artist'].head())
ipd.display(tracks['set'].head())
# Out:
#           bit_rate  comments   composer         date_created  \
# track_id
# 2           256000         0        NaN  2008-11-26 01:48:12
# 3           256000         0        NaN  2008-11-26 01:48:14
# 5           256000         0        NaN  2008-11-26 01:48:20
# 10          192000         0  Kurt Vile  2008-11-25 17:49:06
# 20          256000         0        NaN  2008-11-26 01:48:56
#
#                 date_recorded  duration  favorites genre_top     genres  \
# track_id
# 2         2008-11-26 00:00:00       168          2   Hip-Hop       [21]
# 3         2008-11-26 00:00:00       237          1   Hip-Hop       [21]
# 5         2008-11-26 00:00:00       206          6   Hip-Hop       [21]
# 10        2008-11-26 00:00:00       161        178       Pop       [10]
# 20        2008-01-01 00:00:00       311          0       NaN  [76, 103]
#
#                  genres_all information  interest language_code  \
# track_id
# 2                      [21]         NaN      4656            en
# 3                      [21]         NaN      1470            en
# 5                      [21]         NaN      1933            en
# 10                     [10]         NaN     54881            en
# 20        [17, 10, 76, 103]         NaN       978            en
#
#                                                     license  listens lyricist  \
# track_id
# 2         Attribution-NonCommercial-ShareAlike 3.0 Inter...     1293      NaN
# 3         Attribution-NonCommercial-ShareAlike 3.0 Inter...      514      NaN
# 5         Attribution-NonCommercial-ShareAlike 3.0 Inter...     1151      NaN
# 10        Attribution-NonCommercial-NoDerivatives (aka M...    50135      NaN
# 20        Attribution-NonCommercial-NoDerivatives (aka M...      361      NaN
#
#           number publisher tags            title
# track_id
# 2              3       NaN   []             Food
# 3              4       NaN   []     Electric Ave
# 5              6       NaN   []       This World
# 10             1       NaN   []          Freeway
# 20             3       NaN   []  Spiritual Level
#           comments         date_created        date_released engineer  \
# track_id
# 2                0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 3                0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 5                0  2008-11-26 01:44:45  2009-01-05 00:00:00      NaN
# 10               0  2008-11-26 01:45:08  2008-02-06 00:00:00      NaN
# 20               0  2008-11-26 01:45:05  2009-01-06 00:00:00      NaN
#
#           favorites  id                                information  listens  \
# track_id
# 2                 4   1                                    <p></p>     6073
# 3                 4   1                                    <p></p>     6073
# 5                 4   1                                    <p></p>     6073
# 10                4   6                                        NaN    47632
# 20                2   4  <p> "spiritual songs" from Nicky Cook</p>     2710
#
#          producer tags                 title  tracks   type
# track_id
# 2             NaN   []  AWOL - A Way Of Life       7  Album
# 3             NaN   []  AWOL - A Way Of Life       7  Album
# 5             NaN   []  AWOL - A Way Of Life       7  Album
# 10            NaN   []     Constant Hitmaker       2  Album
# 20            NaN   []                 Niris      13  Album
#             active_year_begin      active_year_end  \
# track_id
# 2         2006-01-01 00:00:00                  NaN
# 3         2006-01-01 00:00:00                  NaN
# 5         2006-01-01 00:00:00                  NaN
# 10                        NaN                  NaN
# 20        1990-01-01 00:00:00  2011-01-01 00:00:00
#
#                                           associated_labels  \
# track_id
# 2                                                       NaN
# 3                                                       NaN
# 5                                                       NaN
# 10        Mexican Summer, Richie Records, Woodsist, Skul...
# 20                                                      NaN
#
#                                                         bio  comments  \
# track_id
# 2         <p>A Way Of Life, A Collective of Hip-Hop from...         0
# 3         <p>A Way Of Life, A Collective of Hip-Hop from...         0
# 5         <p>A Way Of Life, A Collective of Hip-Hop from...         0
# 10        <p><span style="font-family:Verdana, Geneva, A...         3
# 20        <p>Songs written by: Nicky Cook</p>\n<p>VOCALS...         2
#
#                  date_created  favorites  id   latitude            location  \
# track_id
# 2         2008-11-26 01:42:32          9   1  40.058324          New Jersey
# 3         2008-11-26 01:42:32          9   1  40.058324          New Jersey
# 5         2008-11-26 01:42:32          9   1  40.058324          New Jersey
# 10        2008-11-26 01:42:55         74   6        NaN                 NaN
# 20        2008-11-26 01:42:52         10   4  51.895927  Colchester England
#
#           longitude                                            members  \
# track_id
# 2        -74.405661  Sajje Morocco,Brownbum,ZawidaGod,Custodian of ...
# 3        -74.405661  Sajje Morocco,Brownbum,ZawidaGod,Custodian of ...
# 5        -74.405661  Sajje Morocco,Brownbum,ZawidaGod,Custodian of ...
# 10              NaN                           Kurt Vile, the Violators
# 20         0.891874                                       Nicky Cook\n
#
#                 name                                   related_projects  \
# track_id
# 2               AWOL  The list of past projects is 2 long but every1...
# 3               AWOL  The list of past projects is 2 long but every1...
# 5               AWOL  The list of past projects is 2 long but every1...
# 10         Kurt Vile                                                NaN
# 20        Nicky Cook                                                NaN
#
#                                                        tags  \
# track_id
# 2                                                  ['awol']
# 3                                                  ['awol']
# 5                                                  ['awol']
# 10                                  ['philly', 'kurt vile']
# 20        ['instrumentals', 'experimental pop', 'post pu...
#
#                                           website wikipedia_page
# track_id
# 2         http://www.AzillionRecords.blogspot.com            NaN
# 3         http://www.AzillionRecords.blogspot.com            NaN
# 5         http://www.AzillionRecords.blogspot.com            NaN
# 10                            http://kurtvile.com            NaN
# 20                                            NaN            NaN
#              split  subset
# track_id
# 2         training   small
# 3         training  medium
# 5         training   small
# 10        training   small
# 20        training   large

# %%
tracks = tracks[tracks['set', 'subset'] == 'small']
work_df_training = work_df[work_df['set', 'split'] =='training']
work_df_test = work_df[work_df['set', 'split'] =='test']

# %%
features = pd.read_csv('Data/fma_metadata/fma_metadata/features.csv', header=[0,1,2], index_col=0).loc[tracks.index]
features_training = features.loc[work_df_training.index]
features_test = features.loc[work_df_test.index]
features.head()
# Out:
# feature    chroma_cens                                                    \
# statistics    kurtosis
# number              01        02        03        04        05        06
# track_id
# 2             7.180653  5.230309  0.249321  1.347620  1.482478  0.531371
# 5             0.527563 -0.077654 -0.279610  0.685883  1.937570  0.880839
# 10            3.702245 -0.291193  2.196742 -0.234449  1.367364  0.998411
# 140           0.533579 -0.623885 -1.086205 -1.081079 -0.765151 -0.072282
# 141           0.172898 -0.284804 -1.169662 -1.062855 -0.706868 -0.708281
#
# feature                                             ...   tonnetz            \
# statistics                                          ...       std
# number            07        08        09        10  ...        04        05
# track_id                                            ...
# 2           1.481593  2.691455  0.866868  1.341231  ...  0.054125  0.012226
# 5          -0.923192 -0.927232  0.666617  1.038546  ...  0.040730  0.012691
# 10          1.770694  1.604566  0.521217  1.982386  ...  0.074358  0.017952
# 140        -0.882913 -0.582376 -0.884749 -0.645214  ...  0.157683  0.028070
# 141        -0.204884  0.023624 -0.642770 -0.786291  ...  0.145994  0.024342
#
# feature                     zcr                                          \
# statistics             kurtosis       max      mean    median       min
# number            06         01        01        01        01        01
# track_id
# 2           0.012111   5.758890  0.459473  0.085629  0.071289  0.000000
# 5           0.014759   6.808415  0.375000  0.053114  0.041504  0.000000
# 10          0.013921  21.434212  0.452148  0.077515  0.071777  0.000000
# 140         0.025946  11.052547  0.379395  0.052379  0.036621  0.001953
# 141         0.032111  32.994659  0.415527  0.040267  0.034668  0.002930
#
# feature
# statistics      skew       std
# number            01        01
# track_id
# 2           2.089872  0.061448
# 5           2.193303  0.044861
# 10          3.542325  0.040800
# 140         3.143968  0.057712
# 141         4.204097  0.028665
#
# [5 rows x 518 columns]

# %%
genres = pd.read_csv('Data/fma_metadata/fma_metadata/genres.csv')
genres_sorted = genres.sort_values(by='#tracks', ascending=False)

cdf = np.array(genres_sorted['#tracks']).cumsum()/np.array(genres_sorted['#tracks']).sum()

fig, axs= plt.subplots()
axs.plot(cdf)

# %%
plt.scatter(tracks['artist', 'longitude'], tracks['artist', 'latitude'])

# %%
x_train = features_training
x_test = features_test
y_train = work_df_training['track', 'genre_top']
y_test = work_df_test['track', 'genre_top']

scaler = StandardScaler(copy=False)
scaler.fit_transform(x_train)
scaler.transform(x_test)

pca = PCA(n_components=10)
x_train = pca.fit_transform(x_train)
x_test = pca.transform(x_test)

# %%
classifier = SVC()
classifier.fit(x_train, y_train)
score = classifier.score(x_test, y_test)

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train, y_train)
rfc.predict(x_test)
# Out:
# array(['Pop', 'Hip-Hop', 'Electronic', 'Hip-Hop', 'Electronic', 'Hip-Hop',
#        'Hip-Hop', 'Instrumental', 'Instrumental', 'Hip-Hop', 'Electronic',
#        'Rock', 'Hip-Hop', 'Experimental', 'Pop', 'Rock', 'International',
#        'International', 'Electronic', 'Electronic', 'Instrumental',
#        'Experimental', 'Electronic', 'Electronic', 'Instrumental',
#        'Electronic', 'International', 'Electronic', 'Folk',
#        'Experimental', 'Electronic', 'Experimental', 'Experimental',
#        'International', 'International', 'Experimental', 'Pop', 'Folk',
#        'Rock', 'Folk', 'Instrumental', 'International', 'Rock',
#        'International', 'Folk', 'Pop', 'Experimental', 'Instrumental',
#        'International', 'Pop', 'International', 'Rock', 'Pop',
#        'International', 'International', 'Folk', 'International',
#        'International', 'Experimental', 'International', 'Pop',
#        'Experimental', 'Pop', 'Hip-Hop', 'Folk', 'Folk', 'Pop', 'Folk',
#        'International', 'Rock', 'Folk', 'Folk', 'Instrumental', 'Rock',
#        'Folk', 'Instrumental', 'International', 'International', 'Folk',
#        'Experimental', 'Rock', 'Experimental', 'Pop', 'Rock', 'Folk',
#        'Instrumental', 'Experimental', 'Pop', 'Hip-Hop', 'International',
#        'Folk', 'Experimental', 'International', 'Folk', 'Instrumental',
#        'Instrumental', 'Folk', 'International', 'Instrumental', 'Rock',
#        'Experimental', 'Hip-Hop', 'Hip-Hop', 'Electronic', 'Pop',
#        'Hip-Hop', 'Rock', 'Experimental', 'Rock', 'Electronic', 'Hip-Hop',
#        'Hip-Hop', 'Electronic', 'Electronic', 'Electronic',
#        'Experimental', 'Folk', 'Folk', 'Folk', 'Pop', 'Hip-Hop',
#        'Experimental', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Pop', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'Folk',
#        'Experimental', 'Folk', 'Folk', 'Experimental', 'Folk',
#        'Instrumental', 'Pop', 'Instrumental', 'Experimental', 'Folk',
#        'Rock', 'Rock', 'Experimental', 'Hip-Hop', 'Electronic',
#        'Electronic', 'Electronic', 'Experimental', 'Electronic',
#        'Electronic', 'Electronic', 'Hip-Hop', 'Rock', 'Pop', 'Hip-Hop',
#        'Instrumental', 'Pop', 'Rock', 'International', 'Electronic',
#        'Electronic', 'Electronic', 'Rock', 'Rock', 'Electronic', 'Pop',
#        'Pop', 'Rock', 'International', 'Electronic', 'Experimental',
#        'Rock', 'International', 'Pop', 'International', 'Pop',
#        'Instrumental', 'International', 'Pop', 'Instrumental',
#        'Experimental', 'Hip-Hop', 'International', 'Hip-Hop',
#        'Experimental', 'Hip-Hop', 'Hip-Hop', 'Pop', 'International',
#        'Hip-Hop', 'Electronic', 'Hip-Hop', 'Electronic', 'International',
#        'International', 'Folk', 'Folk', 'Folk', 'Folk', 'Folk', 'Folk',
#        'International', 'International', 'International', 'Folk', 'Pop',
#        'International', 'International', 'International', 'Folk',
#        'International', 'Folk', 'International', 'International', 'Folk',
#        'International', 'International', 'International', 'International',
#        'Folk', 'Instrumental', 'Rock', 'Experimental', 'Hip-Hop',
#        'Electronic', 'Folk', 'Folk', 'Folk', 'Experimental', 'Rock',
#        'International', 'International', 'Folk', 'Experimental',
#        'Instrumental', 'Experimental', 'Folk', 'Instrumental', 'Folk',
#        'Folk', 'International', 'Instrumental', 'Rock', 'Electronic',
#        'Electronic', 'International', 'Electronic', 'Electronic',
#        'International', 'Folk', 'Folk', 'International', 'Experimental',
#        'Folk', 'Electronic', 'Electronic', 'Instrumental', 'Instrumental',
#        'Pop', 'Hip-Hop', 'Folk', 'Rock', 'International', 'International',
#        'International', 'International', 'International', 'Pop', 'Rock',
#        'Pop', 'Pop', 'Rock', 'International', 'Pop', 'Hip-Hop', 'Hip-Hop',
#        'Experimental', 'Pop', 'Instrumental', 'Hip-Hop', 'Rock', 'Pop',
#        'Experimental', 'Experimental', 'Instrumental', 'Rock', 'Hip-Hop',
#        'Rock', 'Electronic', 'Electronic', 'Instrumental', 'Rock',
#        'Instrumental', 'Instrumental', 'International', 'International',
#        'Pop', 'Rock', 'Rock', 'International', 'Folk', 'Experimental',
#        'Hip-Hop', 'Experimental', 'Instrumental', 'Instrumental',
#        'Instrumental', 'Instrumental', 'Electronic', 'Pop',
#        'Instrumental', 'International', 'Rock', 'Pop', 'International',
#        'International', 'International', 'International', 'International',
#        'International', 'International', 'International', 'International',
#        'Pop', 'Pop', 'Hip-Hop', 'Hip-Hop', 'International',
#        'Experimental', 'International', 'Experimental', 'Experimental',
#        'Folk', 'Rock', 'International', 'Rock', 'Experimental',
#        'International', 'Rock', 'Experimental', 'Rock', 'Electronic',
#        'Electronic', 'Hip-Hop', 'Rock', 'Rock', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Electronic', 'Pop', 'Electronic', 'Electronic', 'Folk',
#        'Rock', 'Rock', 'International', 'Folk', 'Rock', 'Experimental',
#        'Experimental', 'Experimental', 'Instrumental', 'Pop',
#        'Electronic', 'Electronic', 'Experimental', 'Electronic',
#        'Electronic', 'Electronic', 'Electronic', 'Hip-Hop', 'Rock',
#        'International', 'Hip-Hop', 'International', 'Instrumental',
#        'Rock', 'Pop', 'Instrumental', 'Electronic', 'Experimental',
#        'Rock', 'Rock', 'Rock', 'Rock', 'Rock', 'International', 'Hip-Hop',
#        'Electronic', 'Pop', 'Folk', 'Instrumental', 'Rock', 'Folk',
#        'International', 'Hip-Hop', 'International', 'Folk',
#        'Instrumental', 'Instrumental', 'Hip-Hop', 'Hip-Hop', 'Folk',
#        'Pop', 'Experimental', 'Hip-Hop', 'Experimental', 'Instrumental',
#        'Electronic', 'International', 'Rock', 'Pop', 'Experimental',
#        'Rock', 'Electronic', 'International', 'Hip-Hop', 'Electronic',
#        'International', 'International', 'Hip-Hop', 'Hip-Hop', 'Pop',
#        'Experimental', 'Hip-Hop', 'Electronic', 'International',
#        'Electronic', 'International', 'Hip-Hop', 'Folk', 'Hip-Hop',
#        'Hip-Hop', 'Hip-Hop', 'Experimental', 'Electronic', 'Hip-Hop',
#        'Experimental', 'Experimental', 'Folk', 'Experimental',
#        'Instrumental', 'International', 'International', 'Pop', 'Rock',
#        'Hip-Hop', 'Folk', 'Folk', 'Folk', 'Folk', 'Folk', 'Folk',
#        'Experimental', 'Rock', 'Folk', 'Rock', 'Electronic',
#        'Experimental', 'Experimental', 'Hip-Hop', 'Hip-Hop',
#        'International', 'International', 'International', 'Pop', 'Rock',
#        'Pop', 'Pop', 'International', 'Hip-Hop', 'Hip-Hop',
#        'International', 'Rock', 'Folk', 'Folk', 'International', 'Folk',
#        'Folk', 'Folk', 'Folk', 'Rock', 'Experimental', 'Instrumental',
#        'Pop', 'Rock', 'Rock', 'International', 'International', 'Pop',
#        'Pop', 'Pop', 'Hip-Hop', 'Pop', 'Electronic', 'Electronic',
#        'Electronic', 'Electronic', 'Electronic', 'Hip-Hop', 'Electronic',
#        'Electronic', 'International', 'Electronic', 'Electronic',
#        'Hip-Hop', 'Hip-Hop', 'Hip-Hop', 'Rock', 'Electronic', 'Hip-Hop',
#        'Hip-Hop', 'Rock', 'Hip-Hop', 'International', 'International',
#        'Instrumental', 'Folk', 'International', 'Instrumental',
#        'Electronic', 'Hip-Hop', 'Hip-Hop', 'Hip-Hop', 'Hip-Hop',
#        'International', 'Hip-Hop', 'Electronic', 'Hip-Hop', 'Hip-Hop',
#        'Hip-Hop', 'Pop', 'Electronic', 'Electronic', 'International',
#        'Experimental', 'International', 'Folk', 'International',
#        'Instrumental', 'Instrumental', 'Instrumental', 'Hip-Hop',
#        'Hip-Hop', 'Hip-Hop', 'Electronic', 'Hip-Hop', 'Rock',
#        'Experimental', 'Rock', 'Rock', 'Hip-Hop', 'Electronic',
#        'Instrumental', 'Hip-Hop', 'Hip-Hop', 'Hip-Hop', 'Electronic',
#        'Electronic', 'Pop', 'Folk', 'Hip-Hop', 'Rock', 'Pop',
#        'International', 'International', 'Folk', 'Experimental', 'Folk',
#        'Rock', 'Experimental', 'Instrumental', 'Instrumental', 'Folk',
#        'Instrumental', 'Experimental', 'Folk', 'Folk', 'International',
#        'Folk', 'Folk', 'Folk', 'Folk', 'Hip-Hop', 'Rock', 'Hip-Hop',
#        'Hip-Hop', 'Rock', 'Folk', 'Folk', 'Instrumental', 'Experimental',
#        'Instrumental', 'Instrumental', 'Pop', 'Rock', 'Rock', 'Rock',
#        'Rock', 'Electronic', 'Experimental', 'Instrumental',
#        'Experimental', 'Instrumental', 'Folk', 'Folk', 'Folk',
#        'International', 'Rock', 'Rock', 'Hip-Hop', 'Hip-Hop', 'Pop',
#        'Electronic', 'Pop', 'Instrumental', 'Rock', 'Instrumental',
#        'Experimental', 'Experimental', 'Rock', 'Pop', 'Instrumental',
#        'Experimental', 'Electronic', 'Rock', 'Rock', 'Instrumental',
#        'Rock', 'Experimental', 'Pop', 'Instrumental', 'Folk',
#        'Instrumental', 'Experimental', 'Instrumental', 'Folk', 'Pop',
#        'Pop', 'Pop', 'Folk', 'Folk', 'Pop', 'Folk', 'Pop', 'Folk',
#        'Instrumental', 'Folk', 'Pop', 'Folk', 'Folk', 'Rock', 'Hip-Hop',
#        'International', 'Instrumental', 'Folk', 'Instrumental',
#        'Instrumental', 'Instrumental', 'Instrumental', 'Folk', 'Folk',
#        'Instrumental', 'Instrumental', 'Pop', 'Rock', 'Rock', 'Rock',
#        'Rock', 'International', 'Hip-Hop', 'Rock', 'Instrumental', 'Folk',
#        'Folk', 'Rock', 'Instrumental', 'Folk', 'Instrumental', 'Rock',
#        'Instrumental', 'Folk', 'Instrumental', 'Pop', 'Instrumental',
#        'Instrumental', 'Rock', 'Rock', 'Pop', 'Instrumental',
#        'Experimental', 'Pop', 'Instrumental', 'Instrumental',
#        'Instrumental', 'Folk', 'Instrumental', 'Instrumental', 'Folk',
#        'Experimental', 'Folk', 'Rock', 'Electronic', 'Electronic',
#        'Hip-Hop', 'Electronic', 'Experimental', 'Hip-Hop', 'Electronic',
#        'Hip-Hop', 'Hip-Hop', 'Electronic', 'Electronic', 'Folk',
#        'Electronic', 'Pop', 'Electronic', 'Electronic', 'Instrumental',
#        'Electronic', 'Folk', 'Pop', 'International', 'Electronic',
#        'Experimental', 'Rock', 'Electronic', 'Hip-Hop', 'Hip-Hop',
#        'Electronic', 'Pop', 'Rock', 'Rock', 'Hip-Hop', 'Hip-Hop', 'Pop',
#        'Pop', 'Folk', 'Hip-Hop', 'Hip-Hop', 'Hip-Hop', 'Electronic',
#        'Hip-Hop', 'Experimental', 'Rock', 'Rock', 'Folk', 'Folk',
#        'Experimental', 'Instrumental', 'Instrumental', 'Hip-Hop',
#        'Hip-Hop', 'Hip-Hop', 'Hip-Hop', 'Electronic', 'Folk', 'Folk',
#        'Folk', 'Rock', 'Hip-Hop', 'Hip-Hop', 'Hip-Hop', 'Hip-Hop',
#        'Hip-Hop', 'International', 'Hip-Hop', 'Experimental', 'Pop',
#        'Pop', 'Folk', 'Pop', 'Rock', 'Rock', 'Pop', 'Electronic', 'Pop',
#        'Pop', 'Rock', 'International', 'International', 'International',
#        'Pop', 'Hip-Hop', 'Hip-Hop', 'Rock', 'Electronic', 'Electronic',
#        'Instrumental', 'Electronic', 'International', 'Instrumental',
#        'International'], dtype=object)
